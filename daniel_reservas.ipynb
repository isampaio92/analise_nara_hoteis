# %%
import pandas as pd
import numpy as np

print("OK", pd.__version__)
# Out:
# OK 3.0.2

# %%
dados = 'reservas.csv'
df = pd.read_csv(dados, sep=',')
df.head()
# Out:
#    id_reserva  id_hospede id_quarto  id_hotel data_checkin data_checkout  \
# 0           1         203      Q026         3   2024-10-28    2024-10-29
# 1           2          30      Q033         3   2024-06-03    2024-06-07
# 2           3          47      Q004         1   2024-07-18    2024-07-25
# 3           4         322      Q023         2   2024-08-19    2024-08-20
# 4           5         286      Q013         2   2023-05-17    2023-05-22
#
#        canal_reserva  valor_diaria status_reserva data_reserva
# 0       Site Próprio       2344.25     Confirmada   2024-10-21
# 1       Site Próprio        469.17     Confirmada   2024-05-07
# 2       Site Próprio       2358.47     Confirmada   2024-07-10
# 3           Telefone       1743.13     Confirmada   2024-08-15
# 4  Agência de Viagem        617.85     Confirmada   2023-05-09

# %%
dados = 'reservas.csv'
df = pd.read_csv(dados, sep=',')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_reserva      1000 non-null   int64
#  1   id_hospede      1000 non-null   int64
#  2   id_quarto       1000 non-null   str
#  3   id_hotel        1000 non-null   int64
#  4   data_checkin    1000 non-null   str
#  5   data_checkout   1000 non-null   str
#  6   canal_reserva   995 non-null    str
#  7   valor_diaria    997 non-null    float64
#  8   status_reserva  1000 non-null   str
#  9   data_reserva    1000 non-null   str
# dtypes: float64(1), int64(3), str(6)
# memory usage: 78.3 KB

# %%
#É necessário alterar o "id_quarto", pois o "Q" está interferindo e transformando o Dtype em str
#df["id_quarto"] = df[""].astype(str)


# Sanear a coluna "status_reservada": Temos (Confirmada , confirmada, CONFIRMADA), (Cancelada, Cancelado) (no-show, No-show)
